# %%
import pandas as pd
import json

json_str = '{"name": ["Alice", "Bob"], "age": [25, 30]}'
data = json.loads(json_str)

df = pd.DataFrame(data)
df.to_csv("data.csv")
df
# Out:
#     name  age
# 0  Alice   25
# 1    Bob   30
